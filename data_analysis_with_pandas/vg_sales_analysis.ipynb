# %%
import pandas as pd

# Setting to make numbers easier to read on display
pd.options.display.float_format = '{:20.2f}'.format

# %% [markdown]
# # Loading Data into a Pandas DataFrame
#
# # Data Inspection
#
# #Analysis
#
# ### Questions that we have for the data:

# %%
df = pd.read_csv("/content/drive/MyDrive/PY/Data Analysis/TrentDoesMath/Video Game Sales/vgsales.csv")
df.head()
# Out:
#    Rank                      Name Platform                 Year         Genre  \
# 0     1                Wii Sports      Wii              2006.00        Sports
# 1     2         Super Mario Bros.      NES              1985.00      Platform
# 2     3            Mario Kart Wii      Wii              2008.00        Racing
# 3     4         Wii Sports Resort      Wii              2009.00        Sports
# 4     5  Pokemon Red/Pokemon Blue       GB              1996.00  Role-Playing
#
#   Publisher             NA_Sales             EU_Sales             JP_Sales  \
# 0  Nintendo                41.49                29.02                 3.77
# 1  Nintendo                29.08                 3.58                 6.81
# 2  Nintendo                15.85                12.88                 3.79
# 3  Nintendo                15.75                11.01                 3.28
# 4  Nintendo                11.27                 8.89                10.22
#
#            Other_Sales         Global_Sales
# 0                 8.46                82.74
# 1                 0.77                40.24
# 2                 3.31                35.82
# 3                 2.96                33.00
# 4                 1.00                31.37

# %% [markdown]
# #Data Inspection

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
df.describe()
# Out:
#                       Rank                 Year             NA_Sales  \
# count             16598.00             16327.00             16598.00
# mean               8300.61              2006.41                 0.26
# std                4791.85                 5.83                 0.82
# min                   1.00              1980.00                 0.00
# 25%                4151.25              2003.00                 0.00
# 50%                8300.50              2007.00                 0.08
# 75%               12449.75              2010.00                 0.24
# max               16600.00              2020.00                41.49
#
#                   EU_Sales             JP_Sales          Other_Sales  \
# count             16598.00             16598.00             16598.00
# mean                  0.15                 0.08                 0.05
# std                   0.51                 0.31                 0.19
# min                   0.00                 0.00                 0.00
# 25%                   0.00                 0.00                 0.00
# 50%                   0.02                 0.00                 0.01
# 75%                   0.11                 0.04                 0.04
# max                  29.02                10.22                10.57
#
#               Global_Sales
# count             16598.00
# mean                  0.54
# std                   1.56
# min                   0.01
# 25%                   0.06
# 50%                   0.17
# 75%                   0.47
# max                  82.74

# %%
df.describe(include=[object])
# Out:
#                                Name Platform   Genre        Publisher
# count                         16598    16598   16598            16540
# unique                        11493       31      12              578
# top     Need for Speed: Most Wanted       DS  Action  Electronic Arts
# freq                             12     2163    3316             1351

# %% [markdown]
# # Analysis
#
# Questions that we have for the data:
#
# *Which videogame had the highest sales in 2010?
# *Which game genre is most popular in each year?
# *What are the global sales per year?
# *What are the sales trends per region over time?

# %%
df[df["Year"] == 2010]
# Out:
#         Rank                                               Name Platform  \
# 15        16                                 Kinect Adventures!     X360
# 26        27                        Pokemon Black/Pokemon White       DS
# 31        32                            Call of Duty: Black Ops     X360
# 40        41                            Call of Duty: Black Ops      PS3
# 54        55                                     Gran Turismo 5      PS3
# ...      ...                                                ...      ...
# 16437  16440              The Cages: Pro Style Batting Practice      Wii
# 16478  16481                 Ishin no Arashi: Shippuu Ryuumeden       DS
# 16487  16490          Slotter Mania P: Tetsuya Shinjuku vs Ueno      PSP
# 16501  16504  Transformers: War for Cybertron (XBox 360, PS3...       PC
# 16596  16599                                         Know How 2       DS
#
#                       Year         Genre                     Publisher  \
# 15                 2010.00          Misc        Microsoft Game Studios
# 26                 2010.00  Role-Playing                      Nintendo
# 31                 2010.00       Shooter                    Activision
# 40                 2010.00       Shooter                    Activision
# 54                 2010.00        Racing   Sony Computer Entertainment
# ...                    ...           ...                           ...
# 16437              2010.00        Sports  Konami Digital Entertainment
# 16478              2010.00      Strategy                    Tecmo Koei
# 16487              2010.00          Misc                        Dorart
# 16501              2010.00       Shooter                    Activision
# 16596              2010.00        Puzzle                      7G//AMES
#
#                   NA_Sales             EU_Sales             JP_Sales  \
# 15                   14.97                 4.94                 0.24
# 26                    5.57                 3.28                 5.65
# 31                    9.67                 3.73                 0.11
# 40                    5.98                 4.44                 0.48
# 54                    2.96                 4.88                 0.81
# ...                    ...                  ...                  ...
# 16437                 0.01                 0.00                 0.00
# 16478                 0.00                 0.00                 0.01
# 16487                 0.00                 0.00                 0.01
# 16501                 0.01                 0.00                 0.00
# 16596                 0.00                 0.01                 0.00
#
#                Other_Sales         Global_Sales
# 15                    1.67                21.82
# 26                    0.82                15.32
# 31                    1.13                14.64
# 40                    1.83                12.73
# 54                    2.12                10.77
# ...                    ...                  ...
# 16437                 0.00                 0.01
# 16478                 0.00                 0.01
# 16487                 0.00                 0.01
# 16501                 0.00                 0.01
# 16596                 0.00                 0.01
#
# [1259 rows x 11 columns]

# %%
df["Global_Sales"].max()
# Out:
# 82.74

# %%
twenty_ten_df = df[df["Year"] == 2010]

twenty_ten_df[twenty_ten_df["Global_Sales"] == twenty_ten_df["Global_Sales"].max()]
# Out:
#     Rank                Name Platform                 Year Genre  \
# 15    16  Kinect Adventures!     X360              2010.00  Misc
#
#                  Publisher             NA_Sales             EU_Sales  \
# 15  Microsoft Game Studios                14.97                 4.94
#
#                JP_Sales          Other_Sales         Global_Sales
# 15                 0.24                 1.67                21.82

# %%
df[["Year", "Global_Sales"]].groupby("Year").max()
# Out:
#                 Global_Sales
# Year
# 1980.00                 4.31
# 1981.00                 4.50
# 1982.00                 7.81
# 1983.00                 3.20
# 1984.00                28.31
# 1985.00                40.24
# 1986.00                 6.51
# 1987.00                 4.38
# 1988.00                17.28
# 1989.00                30.26
# 1990.00                20.61
# 1991.00                 4.61
# 1992.00                11.18
# 1993.00                10.55
# 1994.00                 9.30
# 1995.00                 5.15
# 1996.00                31.37
# 1997.00                10.95
# 1998.00                14.64
# 1999.00                23.10
# 2000.00                 6.39
# 2001.00                14.98
# 2002.00                16.15
# 2003.00                 7.20
# 2004.00                20.81
# 2005.00                24.76
# 2006.00                82.74
# 2007.00                22.72
# 2008.00                35.82
# 2009.00                33.00
# 2010.00                21.82
# 2011.00                14.76
# 2012.00                14.03
# 2013.00                21.40
# 2014.00                11.98
# 2015.00                14.24
# 2016.00                 4.77
# 2017.00                 0.03
# 2020.00                 0.29

# %%
df[["Year", "Global_Sales"]].groupby("Year", as_index=False).max()
# Out:
#                    Year         Global_Sales
# 0               1980.00                 4.31
# 1               1981.00                 4.50
# 2               1982.00                 7.81
# 3               1983.00                 3.20
# 4               1984.00                28.31
# 5               1985.00                40.24
# 6               1986.00                 6.51
# 7               1987.00                 4.38
# 8               1988.00                17.28
# 9               1989.00                30.26
# 10              1990.00                20.61
# 11              1991.00                 4.61
# 12              1992.00                11.18
# 13              1993.00                10.55
# 14              1994.00                 9.30
# 15              1995.00                 5.15
# 16              1996.00                31.37
# 17              1997.00                10.95
# 18              1998.00                14.64
# 19              1999.00                23.10
# 20              2000.00                 6.39
# 21              2001.00                14.98
# 22              2002.00                16.15
# 23              2003.00                 7.20
# 24              2004.00                20.81
# 25              2005.00                24.76
# 26              2006.00                82.74
# 27              2007.00                22.72
# 28              2008.00                35.82
# 29              2009.00                33.00
# 30              2010.00                21.82
# 31              2011.00                14.76
# 32              2012.00                14.03
# 33              2013.00                21.40
# 34              2014.00                11.98
# 35              2015.00                14.24
# 36              2016.00                 4.77
# 37              2017.00                 0.03
# 38              2020.00                 0.29

# %%
max_sales_by_year_df = df[["Year", "Global_Sales"]].groupby("Year", as_index=False).max()

max_sales_by_year_df.merge(df[["Year", "Global_Sales", "Name"]], on=["Year", "Global_Sales"], how="left")
# Out:
#                    Year         Global_Sales  \
# 0               1980.00                 4.31
# 1               1981.00                 4.50
# 2               1982.00                 7.81
# 3               1983.00                 3.20
# 4               1984.00                28.31
# 5               1985.00                40.24
# 6               1986.00                 6.51
# 7               1987.00                 4.38
# 8               1988.00                17.28
# 9               1989.00                30.26
# 10              1990.00                20.61
# 11              1991.00                 4.61
# 12              1992.00                11.18
# 13              1993.00                10.55
# 14              1994.00                 9.30
# 15              1995.00                 5.15
# 16              1996.00                31.37
# 17              1997.00                10.95
# 18              1998.00                14.64
# 19              1999.00                23.10
# 20              2000.00                 6.39
# 21              2001.00                14.98
# 22              2002.00                16.15
# 23              2003.00                 7.20
# 24              2004.00                20.81
# 25              2005.00                24.76
# 26              2006.00                82.74
# 27              2007.00                22.72
# 28              2008.00                35.82
# 29              2009.00                33.00
# 30              2010.00                21.82
# 31              2011.00                14.76
# 32              2012.00                14.03
# 33              2013.00                21.40
# 34              2014.00                11.98
# 35              2015.00                14.24
# 36              2016.00                 4.77
# 37              2017.00                 0.03
# 38              2020.00                 0.29
#
#                                                 Name
# 0                                          Asteroids
# 1                                           Pitfall!
# 2                                            Pac-Man
# 3                                           Baseball
# 4                                          Duck Hunt
# 5                                  Super Mario Bros.
# 6                                The Legend of Zelda
# 7                    Zelda II: The Adventure of Link
# 8                                Super Mario Bros. 3
# 9                                             Tetris
# 10                                 Super Mario World
# 11           The Legend of Zelda: A Link to the Past
# 12                Super Mario Land 2: 6 Golden Coins
# 13                             Super Mario All-Stars
# 14                               Donkey Kong Country
# 15         Donkey Kong Country 2: Diddy's Kong Quest
# 16                          Pokemon Red/Pokemon Blue
# 17                                      Gran Turismo
# 18           Pokémon Yellow: Special Pikachu Edition
# 19                       Pokemon Gold/Pokemon Silver
# 20                           Pokémon Crystal Version
# 21                            Gran Turismo 3: A-Spec
# 22                       Grand Theft Auto: Vice City
# 23                        Need for Speed Underground
# 24                     Grand Theft Auto: San Andreas
# 25                                        Nintendogs
# 26                                        Wii Sports
# 27                                           Wii Fit
# 28                                    Mario Kart Wii
# 29                                 Wii Sports Resort
# 30                                Kinect Adventures!
# 31                    Call of Duty: Modern Warfare 3
# 32                        Call of Duty: Black Ops II
# 33                                Grand Theft Auto V
# 34                                Grand Theft Auto V
# 35                         Call of Duty: Black Ops 3
# 36                                           FIFA 17
# 37  Phantasy Star Online 2 Episode 4: Deluxe Package
# 38                            Imagine: Makeup Artist

# %%
df[["Year", "Global_Sales"]].groupby("Year", as_index=False).sum()
# Out:
#                    Year         Global_Sales
# 0               1980.00                11.38
# 1               1981.00                35.77
# 2               1982.00                28.86
# 3               1983.00                16.79
# 4               1984.00                50.36
# 5               1985.00                53.94
# 6               1986.00                37.07
# 7               1987.00                21.74
# 8               1988.00                47.22
# 9               1989.00                73.45
# 10              1990.00                49.39
# 11              1991.00                32.23
# 12              1992.00                76.16
# 13              1993.00                45.98
# 14              1994.00                79.17
# 15              1995.00                88.11
# 16              1996.00               199.15
# 17              1997.00               200.98
# 18              1998.00               256.47
# 19              1999.00               251.27
# 20              2000.00               201.56
# 21              2001.00               331.47
# 22              2002.00               395.52
# 23              2003.00               357.85
# 24              2004.00               419.31
# 25              2005.00               459.94
# 26              2006.00               521.04
# 27              2007.00               611.13
# 28              2008.00               678.90
# 29              2009.00               667.30
# 30              2010.00               600.45
# 31              2011.00               515.99
# 32              2012.00               363.54
# 33              2013.00               368.11
# 34              2014.00               337.05
# 35              2015.00               264.44
# 36              2016.00                70.93
# 37              2017.00                 0.05
# 38              2020.00                 0.29

# %%
global_sales_per_year_df = df[["Year", "Global_Sales"]].groupby("Year", as_index=False).sum()

global_sales_per_year_df.plot(kind="bar", x="Year", y="Global_Sales", figsize=(15,5), ylabel= "Sales (Millions $)", title="Global VG Sales Over The Years")
# Out:
# <Axes: title={'center': 'Global VG Sales Over The Years'}, xlabel='Year', ylabel='Sales (Millions $)'>

# %%
df.head()
# Out:
#    Rank                      Name Platform                 Year         Genre  \
# 0     1                Wii Sports      Wii              2006.00        Sports
# 1     2         Super Mario Bros.      NES              1985.00      Platform
# 2     3            Mario Kart Wii      Wii              2008.00        Racing
# 3     4         Wii Sports Resort      Wii              2009.00        Sports
# 4     5  Pokemon Red/Pokemon Blue       GB              1996.00  Role-Playing
#
#   Publisher             NA_Sales             EU_Sales             JP_Sales  \
# 0  Nintendo                41.49                29.02                 3.77
# 1  Nintendo                29.08                 3.58                 6.81
# 2  Nintendo                15.85                12.88                 3.79
# 3  Nintendo                15.75                11.01                 3.28
# 4  Nintendo                11.27                 8.89                10.22
#
#            Other_Sales         Global_Sales
# 0                 8.46                82.74
# 1                 0.77                40.24
# 2                 3.31                35.82
# 3                 2.96                33.00
# 4                 1.00                31.37

# %%
df[["Year", "EU_Sales", "JP_Sales", "NA_Sales", "Other_Sales"]].groupby("Year", as_index=False).sum().plot(x="Year", figsize=(15,5))
# Out:
# <Axes: xlabel='Year'>
